# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
G.add_node(0)
G.add_node(1)
G.add_edge(0, 1)

# %%
nx.draw(G)

# %%
a = nx.complete_graph(5)
nx.draw(a, with_labels=True)

# %%
list(a.neighbors(1))
# Out:
# [0, 2, 3, 4]

# %%
a

# %%
a.nodes()
# Out:
# NodeView((0, 1, 2, 3, 4))

# %%
list(a.adjacency())
# Out:
# [(0, {1: {}, 2: {}, 3: {}, 4: {}}),
#  (1, {0: {}, 2: {}, 3: {}, 4: {}}),
#  (2, {0: {}, 1: {}, 3: {}, 4: {}}),
#  (3, {0: {}, 1: {}, 2: {}, 4: {}}),
#  (4, {0: {}, 1: {}, 2: {}, 3: {}})]
